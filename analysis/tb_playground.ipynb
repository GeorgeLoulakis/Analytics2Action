# %%
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
ANALYSIS_DIR = Path().resolve()
DATA_DIR = ANALYSIS_DIR / "data"
OUTPUT_DIR = ANALYSIS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

EXPORT_DPI = 600

# %%
df = pd.read_csv(DATA_DIR / "European_data_2000.csv")

# %%
df.head()
# Out:
#      titleId                                imdbUrl  \
# 0  tt3042384  https://www.imdb.com/title/tt3042384/
# 1  tt2486278  https://www.imdb.com/title/tt2486278/
# 2  tt1361313  https://www.imdb.com/title/tt1361313/
# 3  tt0222124  https://www.imdb.com/title/tt0222124/
# 4  tt0421229  https://www.imdb.com/title/tt0421229/
#
#                                        originalTitle titleType  releaseYear  \
# 0                                                Ida     movie       2013.0
# 1                                         Blood Shed     movie       2013.0
# 2                                      The Extra Man     movie       2010.0
# 3  Se tutte le donne del mondo... (Operazione Par...     movie       1966.0
# 4                       Mrs Palfrey at the Claremont     movie       2005.0
#
#    runtimeMinutes  isAdult  imdbRating  numberOfVotes    allCountries  ...  \
# 0            82.0    False         7.4        61189.0  PL, DK, FR, GB  ...
# 1            99.0    False         3.1          689.0          GB, US  ...
# 2           108.0    False         5.8         5470.0          FR, US  ...
# 3           106.0    False         6.0          434.0          IT, US  ...
# 4           108.0    False         7.6         4382.0          GB, US  ...
#
#                        englishTitle  \
# 0                               Ida
# 1                        Blood Shed
# 2                     The Extra Man
# 3  Kiss the Girls and Make Them Die
# 4      Mrs Palfrey at the Claremont
#
#                                        topFiveActors             directors  \
# 0  nm0474492 (Wanda), nm5531398 (Anna), nm4221607...             nm0667734
# 1  nm4697835 (Gabriel), nm0000499 (Lucy), nm23560...  nm0368530, nm2350538
# 2  nm0200452 (Louis Ives), nm0783033 (Vivian Cudl...  nm0075849, nm0700301
# 3  nm0175528 (Kelly), nm0699063 (Susan Fleming), ...  nm0505610, nm0537985
# 4  nm0687506 (Mrs Palfrey), nm1670029 (Ludo), nm1...             nm0006959
#
#                                       writers  \
# 0                        nm0667734, nm0501947
# 1                                   nm0368530
# 2  nm0700301, nm0024718, nm0024718, nm0075849
# 3             nm0537985, nm0537985, nm0700474
# 4  nm0233026, nm0006959, nm1699869, nm0852331
#
#                                            plotShort  \
# 0  A novice nun about to take her vows uncovers a...
# 1  A homeless loner moves into a self-storage fac...
# 2  A man who escorts wealthy widows in New York's...
# 3  In this spoof of spy films, CIA agent, Kelly, ...
# 4  All but abandoned by her family in a London re...
#
#                                           plotMedium  \
# 0  Poland, 1962. Anna, an orphan brought up by nu...
# 1  Loosely-based on the true events of a homeless...
# 2  Louis, a young teacher enamored of the age of ...
# 3  An outlandish science-fiction, comedy-thriller...
# 4  Mrs. Palfrey (Dame Joan Plowright), recently w...
#
#                                             plotLong            genres  \
# 0  Circa 1962. The movie opens with three noviati...             Drama
# 1  Imagine "people under the stairs" meeting "not...  Horror, Thriller
# 2  Louis is a young bookish prep school teacher w...            Comedy
# 3  An aging playboy, Mr Ardonian, hatches a plan ...    Action, Comedy
# 4  The talented indie director Dan Ireland (The W...     Comedy, Drama
#
#                                             keywords  \
# 0  poland, 1960s, jew, novitiate, family secret, ...
# 1  stalker, female nudity, female topless nudity,...
# 2  new york city, brassiere, painting oneself, ca...
# 3  espionage, american agent, female british spy,...
# 4  hotel, writer, grandson, friendship, impersona...
#
#                                           production
# 0  Music Box Films, Solopan, Orange Entertainment...
# 1  Uncork'd Entertainment, Viva Pictures, Enderby...
# 2  Magnolia Pictures, Mares Filmes, BIM Distribuz...
# 3  Columbia Pictures, Dear Film, Columbia Picture...
# 4  Cineville, Westlake Entertainment Group, Parag...
#
# [5 rows x 23 columns]
